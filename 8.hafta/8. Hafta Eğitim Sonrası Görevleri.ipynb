# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
num_entries = int(input("Kaç kez veri girişi yapmak istersiniz? "))

name = input("İsim: ")
age = int(input("Yaş: "))
height = float(input("Boy (metre cinsinden): "))
weight = float(input("Kilo: "))

vki = weight / (height ** 2)
if vki < 18.5:
    category = "Zayıf"
elif 18.5 <= vki < 25:
    category = "Normal Kilolu"
elif 25 <= vki < 30:
    category = "Fazla Kilolu"
elif 30 <= vki < 40:
    category = "Obez"
else:
    category = "İleri Derecede Obez"

print(f"{name}, VKİ değerin {vki:.2f} ve {category} kategorisindesin.")

import csv

with open('kullanici_verileri.csv', 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow([name, age, height, weight, vki, category])
import csv

num_entries = int(input("Kaç kez veri girişi yapmak istersiniz? "))

for i in range(num_entries):
    name = input("İsim: ")
    age = int(input("Yaş: "))
    height = float(input("Boy (metre cinsinden): "))
    weight = float(input("Kilo: "))

    vki = weight / (height ** 2)

    if vki < 18.5:
        category = "Zayıf"
    elif 18.5 <= vki < 25:
        category = "Normal Kilolu"
    elif 25 <= vki < 30:
        category = "Fazla Kilolu"
    elif 30 <= vki < 40:
        category = "Obez"
    else:
        category = "İleri Derecede Obez"

    print(f"{name}, VKİ değerin {vki:.2f} ve {category} kategorisindesin.")
# Out:
# hamide, VKİ değerin 0.00 ve Zayıf kategorisindesin.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

def menu():
    print("YetBar Spor Salonu İçecek Otomatı")
    print("1. Menüyü Görüntüle")
    print("2. Satın Al")
    choice = input("Lütfen yapmak istediğiniz işlemi seçiniz (1-2): ")
    return choice

def malzeme_sec():
    print("Lütfen kullanmak istediğiniz malzemeleri seçiniz:")
    print("1. Çilek")
    print("2. Muz")
    print("3. Ananas")
    print("4. Elma")
    print("5. Portakal")
    print("6. Yoğurt")
    malzemeler = []
    while True:
        secim = input("Lütfen bir malzeme seçiniz (1-6) (Çıkış için 'q' tuşuna basınız): ")
        if secim == 'q':
            break
        elif secim in ['1', '2', '3', '4', '5', '6']:
            malzemeler.append(secim)
            print(f"{secim}. seçildi.")
        else:
            print("Geçersiz bir seçim yaptınız.")
    return malzemeler

def fiyat_hesapla(malzemeler):
    fiyat = 0
    for malzeme in malzemeler:
        if malzeme in ['1', '2', '3', '4', '5']:
            fiyat += 2.5
        elif malzeme == '6':
            fiyat += 3
    return fiyat

import datetime

# kaydedilecek veriler
tarih = datetime.datetime.now()
tarif = "Muzlu smoothie"
miktar = "2 adet"
fiyat = 15.0

# dosyaya yazma işlemi
with open("smoothie_kayitlari.txt", mode="a") as dosya:
    dosya.write(f"{tarih} - {tarif} ({miktar}): {fiyat} TL\n")
